# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('../input/train_cat.csv')

# %%
data.head()
# Out:
#    id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2       nom_3  \
# 0   0    0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster      Russia
# 1   1    1.0    1.0    0.0     F     Y   Red       Star  Axolotl         NaN
# 2   2    0.0    1.0    0.0     F     N   Red        NaN  Hamster      Canada
# 3   3    NaN    0.0    0.0     F     N   Red     Circle  Hamster     Finland
# 4   4    0.0    NaN    0.0     T     N   Red   Triangle  Hamster  Costa Rica
#
#    ...        nom_9 ord_0        ord_1     ord_2 ord_3 ord_4  ord_5  day  \
# 0  ...    02e7c8990   3.0  Contributor       Hot     c     U     Pw  6.0
# 1  ...    f37df64af   3.0  Grandmaster      Warm     e     X     pE  7.0
# 2  ...          NaN   3.0          NaN  Freezing     n     P     eN  5.0
# 3  ...    f9d456e57   1.0       Novice  Lava Hot     a     C    NaN  3.0
# 4  ...    c5361037c   3.0  Grandmaster      Cold     h     C     OZ  5.0
#
#   month target
# 0   3.0      0
# 1   7.0      0
# ...

# %% [markdown]
# # Ordinal Variables

# %%
cols = ['ord_0','ord_1','ord_2','ord_3','ord_4','ord_5']

# %%
for col in cols:
    print(f'{col}')
    print(data[col].value_counts())
# Out:
# ord_0
# 1.0    227917
# 3.0    197798
# 2.0    155997
# Name: ord_0, dtype: int64
# ord_1
# Novice         160597
# Expert         139677
# Contributor    109821
# Grandmaster     95866
# Master          75998
# Name: ord_1, dtype: int64
# ord_2
# Freezing       142726
# Warm           124239
# Cold            97822
# Boiling Hot     84790
# Hot             67508
# Lava Hot        64840
# Name: ord_2, dtype: int64
# ord_3
# n    70982
# a    65321
# m    57980
# c    56675
# h    55744
# o    45464
# b    44795
# e    38904
# k    38718
# i    34763
# d    30634
# f    29450
# g     6180
# j     3639
# l     2835
# Name: ord_3, dtype: int64
# ord_4
# N    39978
# P    37890
# Y    36657
# A    36633
# R    33045
# U    32897
# M    32504
# X    32347
# C    32112
# H    31189
# Q    30145
# T    29723
# O    25610
# B    25212
# E    21871
# K    21676
# I    19805
# D    17284
# F    16721
# W     8268
# Z     5790
# S     4595
# G     3404
# V     3107
# J     1950
# L     1657
# ...

# %%
data.shape[0]
# Out:
# 600000

# %%
def get_stats(group):
    return { 
            'count': group.count(), 'mean': group.mean()}

# %%
data['target'].groupby(data['ord_1']).apply(get_stats).unstack()
# Out:
#                 count      mean
# ord_1
# Contributor  109821.0  0.172972
# Expert       139677.0  0.189716
# Grandmaster   95866.0  0.232669
# Master        75998.0  0.211650
# Novice       160597.0  0.156024

# %%
col = 'ord_1'

# %%
def get_stats(data,col_list,target):

    main_stats = pd.DataFrame(columns = ['Feature','Levels','Class count','Event count','Non-Event count'])
    data_change = data
    for col in col_list:

        data_filter = data.dropna(subset = [col])
        elements = data_filter[col].unique().tolist()

        for element in elements:
            stats ={}

            stats['Feature'] = col
            stats['Levels'] = element
            stats['Class count'] = data_filter[data_filter[col]==element].shape[0]
            stats['Event count'] = data_filter[data_filter[col]==element].loc[data_filter[target]==1,].shape[0]
            stats['Non-Event count'] = data_filter[data_filter[col]==element].loc[data_filter[target]==0,].shape[0]

            #ClassCount.append(data[data[col]==element].shape[0])
            #Event_Count.append(data[data[col]==element][data['target']==1].shape[0])
            #Non_Event_Count.append(data[data[col]==element][data['target']==0].shape[0])

            main_stats =main_stats.append(stats,ignore_index = True)

    return main_stats

# %%
columns = ['ord_0','ord_1','ord_2','ord_3','ord_4','ord_5']

# %%
a = get_stats(data,columns,'target')

# %%
import pandas as pd

writer = pd.ExcelWriter('title.xlsx', engine='xlsxwriter')

a.to_excel(writer, sheet_name='Categorical')

# %%
writer.save()

# %%
import os
os.getcwd()
# Out:
# '/home/aditya/Kaggle/workspace/ml-proj-template/notebooks'

# %%
a.to
# Out:
#     Feature       Levels Class count Event count Non-Event count
# 0     ord_0            3      191801       45991          145810
# 1     ord_0            1      221149       31421          189728
# 2     ord_0            2      151282       28202          123080
# 3     ord_1  Contributor      109821       18996           90825
# 4     ord_1  Grandmaster       95866       22305           73561
# 5     ord_1       Novice      160597       25057          135540
# 6     ord_1       Expert      139677       26499          113178
# 7     ord_1       Master       75998       16085           59913
# 8     ord_2          Hot       65469       13439           52030
# 9     ord_2         Warm      120570       21137           99433
# 10    ord_2     Lava Hot       62942       18307           44635
# 11    ord_2         Cold       94789       14438           80351
# 12    ord_2  Boiling Hot       82252       20059           62193
# ...

# %%
data = data.dropna(subset = [col])
elements = data[col].unique().tolist()

ClassCount,Event_Count,Non_Event_Count = [],[],[]

main_stats = pd.DataFrame(columns = ['element','class count','event count','non event count'])

# %%
main_stats
# Out:
# Empty DataFrame
# Columns: [element, class count, event count, non event count]
# Index: []

# %%
element  = elements[1]

# %%
element
# Out:
# 'Contributor'

# %%
for element in elements:

# %%
stats={}
stats['element'] = element
stats['class count'] = data[data[col]==element].shape[0]
stats['event count'] = data[data[col]==element][data['target']==1].shape[0]
stats['non event count'] = data[data[col]==element][data['target']==0].shape[0]
# Out:
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
#ClassCount.append(data[data[col]==element].shape[0])
#Event_Count.append(data[data[col]==element][data['target']==1].shape[0])
#Non_Event_Count.append(data[data[col]==element][data['target']==0].shape[0])
print(stats)
# Out:
# {'element': 'Grandmaster', 'class count': 95866, 'event count': 22305, 'non event count': 73561}

# %%
main_stats.append(stats,ignore_index = True)
# Out:
#        element class count event count non event count
# 0  Grandmaster       95866       22305           73561

# %%
main_stats
# Out:
# Empty DataFrame
# Columns: [element, class count, event count, non event count]
# Index: []

# %%
elements, ClassCount,Event_Count,Non_Event_Count = get_stats(data,'ord_0')
# Out:
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# /home/aditya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
elements, ClassCount,Event_Count,Non_Event_Count
# Out:
# ([3.0, 1.0, 2.0],
#  [197798, 227917, 155997],
#  [47427, 32378, 29097],
#  [150371, 195539, 126900])
